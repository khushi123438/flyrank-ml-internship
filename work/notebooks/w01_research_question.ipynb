# %% [markdown]
# <a href="https://colab.research.google.com/github/khushi123438/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khushi123438/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My lane: Search Performance Improvement
#
# I want to understand which factors are related to better search performance, especially how page-level metrics relate to user engagement. This lane is useful because improving search performance can help users find more relevant content and improve overall experience. I want to identify patterns in the data that can support better decisions.

# %%
import pandas as pd
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv
# ./sample_data/mnist_test.csv

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Decision:
# Which pages should be prioritized for improvement based on their search performance?
#
# Action:
# A team can use these insights to identify pages that may need optimization and decide where to spend improvement efforts.
#
# Cost of a wrong recommendation:
# A wrong recommendation could waste time and resources on pages that do not need changes and may cause important opportunities to be missed.

# %%
print("Decision-support analysis: identifying patterns in search performance data.")
# Out:
# Decision-support analysis: identifying patterns in search performance data.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/khushi123438/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 143 (delta 55), reused 101 (delta 34), pack-reused 0 (from 0)
# Receiving objects: 100% (143/143), 1.85 MiB | 13.70 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
import os

for root, dirs, files in os.walk("/content/flyrank-ml-internship"):
    for file in files:
        if file.endswith(".csv"):
            print(root+"/"+file)
# Out:
# /content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv
# /content/flyrank-ml-internship/outputs/refresh_queue_sample.csv

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This work can identify observed patterns and directional relationships in the available data. It can support decisions by highlighting areas worth investigating.
#
# This work cannot prove causal relationships, explain Google's ranking algorithm, or claim that one factor directly causes another.

# %%
print("Analysis focuses on observed patterns and decision support.")
# Out:
# Analysis focuses on observed patterns and decision support.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ done ] Every section above is filled — markdown thinking AND the code that backs it
# - [ done ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ done ] No client names, URLs, or private queries anywhere
# - [ done ] My claims use careful words: observed, measured, directional, decision-support
# - [ done ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
